# %% [markdown]
# # 5.3 - Web Scraping (bs4)
#
#
# ![scraping](images/scraping.png)
#
#
# Web scraping o raspado web, es una técnica utilizada mediante programas de software para extraer información de sitios web. Usualmente, estos programas simulan la navegación de un humano en la web ya sea utilizando el protocolo HTTP manualmente, o incrustando un navegador en una aplicación.
#
# El web scraping está muy relacionado con la indexación de la web, la cual indexa la información de la web utilizando un robot y es una técnica universal adoptada por la mayoría de los motores de búsqueda. Sin embargo, el web scraping se enfoca más en la transformación de datos sin estructura en la web, como el formato HTML, en datos estructurados que pueden ser almacenados y analizados en una base de datos central, en una hoja de cálculo o en alguna otra fuente de almacenamiento. Alguno de los usos del web scraping son la comparación de precios en tiendas, la monitorización de datos relacionados con el clima de cierta región, la detección de cambios en sitios webs y la integración de datos en sitios webs.
#
# En los últimos años el web scraping se ha convertido en una técnica muy utilizada dentro del sector del posicionamiento web gracias a su capacidad de generar grandes cantidades de datos para crear contenidos de calidad.
#
# Podríamos pensar que el web scraping es nuestro último recurso a falta de una API o un feed RSS. A falta de una fuente de datos, siempre podemos extraer aquello que sale por pantalla.

# %% [markdown]
# ### Extracción desde el HTML
#
# Para scrapear una página web, en primer lugar debemos conocer las estructura que tiene el HTML. Veamos la estructura básica.
#
# El HTML consiste en contenido `<etiquetado>`, es como si fueran cajas de contenido, organizado de manera jerárquica:
#
# ```
# <html>
#     <head>
#         <title>Titulo de la pagina</title>
#     </head>
#     <body>
#         <h1>Cabecera</h1>
#         <p>Parrafo</p>
#     </body>
# </html>
# ```
#
# $$$$
#
# Las etiquetas el HTML se pueden clasificar en varios grupos, dependiendo del tipo de contenido que posea. Estos son algunos ejemplos:
#
# + cabecera: `<h1>`, `<h2>`, `<h3>`, `<hgroup>`...
# + texto: `<b>`, `<p>`...
# + embebido: `<audio>`, `<img>`, `<video>`...
# + tabular: `<table>`, `<tr>`, `<td>`, `<tbody>`...
# + secciones: `<header>`, `<section>`, `<article>`...
# + metadata: `<meta>`, `<title>`, `<script>`...
#
# $$$$
#
# Las etiquetas pueden tener atributos. Por ejemplo:
#
# `<div class="text-monospace" id="name_132", href="www.example.com"> Contenido de la pagina </div>`
#
# Esta etiqueta `div` tiene los siguientes atributos:
#
# + class: atributo con valor "text-monospace". La clase no es única en la página.
# + id: atributo con valor "name_132". El id de una etiqueta la identifica de manera unívoca.
# + href: atributo con valor "www.example.com". El href suele contener el link a otra parte de la página.
#
# Siguiendo con la analogía de las cajas, si una etiqueta de HTML es una caja, los atributos serían las pegatinas pegadas en la tapa de la caja.
#
# Conociendo cual es el contenido que queremos extraer, debemos encontrar las etiquetas dentro del HTML de la página web.

# %% [markdown]
# Usaremos la herramienta **[BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)**.

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\anaconda3\lib\site-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\anaconda3\lib\site-packages (from beautifulsoup4) (2.2.1)

# %%
import requests as req

from bs4 import BeautifulSoup as bs

# %% [markdown]
# ### Ejemplos Wikipedia
#
# **[Países europeos según esperanza de vida](https://en.wikipedia.org/wiki/List_of_European_countries_by_life_expectancy)**

# %%
url='https://en.wikipedia.org/wiki/List_of_European_countries_by_life_expectancy'

# %%
# usamos requests para extraer el HTML

html=req.get(url).content # o .text

html[:1000]
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of European countries by life expectancy - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"11ee96e1-64bd-4992-be43-d2c991813980","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_European_countries_by_life_expectancy","wgTitle":"List of European countries by life expectancy","wgCurRevisionId":1049636953,"wgRevisionId":1049636953,"wgArticleId":22175559,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description is different from '

# %%
# bs4 para el manejo del html

soup=bs(html, 'html.parser')

type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# unica tabla en la pagina

tabla=soup.find('table')  # find saca solo el primero, devuelve elemento

type(tabla)
# Out:
# bs4.element.Tag

# %%
# extraccion de las filas de la tabla

filas=tabla.find_all('tr')   # find_all saca todos, devuelve una lista

filas=[f.text.strip().split('\n') for f in filas]

filas[:5]
# Out:
# [['Rank',
#   '',
#   'Country',
#   'Life expectancy[1]',
#   '',
#   'Influenza vaccination rate, people aged 65 and over, 2016 (%)[2]'],
#  ['1', '', '\xa0Monaco[3]', '', '89.4'],
#  ['2', '', '\xa0San Marino[4]', '', '83.4'],
#  ['3', '', '\xa0\xa0Switzerland', '83.0'],
#  ['4', '', '\xa0Spain', '82.8', '', '56%']]

# %%
# minima limpieza, quitar strings vacias

final=[]

for fila in filas:
    
    tmp=[]
    
    for palabra in fila:
        
        if palabra!='':
            
            tmp.append(palabra)
            
    final.append(tmp)
    
final[:5]
# Out:
# [['Rank',
#   'Country',
#   'Life expectancy[1]',
#   'Influenza vaccination rate, people aged 65 and over, 2016 (%)[2]'],
#  ['1', '\xa0Monaco[3]', '89.4'],
#  ['2', '\xa0San Marino[4]', '83.4'],
#  ['3', '\xa0\xa0Switzerland', '83.0'],
#  ['4', '\xa0Spain', '82.8', '56%']]

# %%
import pandas as pd

col_names=final[0]

data=final[1:]

df=pd.DataFrame(data, columns=col_names)

df.head(10)
# Out:
#   Rank         Country Life expectancy[1]  \
# 0    1       Monaco[3]               89.4
# 1    2   San Marino[4]               83.4
# 2    3     Switzerland               83.0
# 3    4           Spain               82.8
# 4    5   Liechtenstein               82.7
# 5    6           Italy               82.7
# 6    7          Norway               82.5
# 7    8         Iceland               82.5
# 8    9      Luxembourg               82.3
# 9   10          France               82.3
#
#   Influenza vaccination rate, people aged 65 and over, 2016 (%)[2]
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                                56%
# 4                                                28%
# 5                                                50%
# 6                                                38%
# 7                                                47%
# 8                                                38%
# 9                                                50%

# %% [markdown]
# $$$$
#
# **[Medallero Barcelona'92](https://es.wikipedia.org/wiki/Juegos_Ol%C3%ADmpicos_de_Barcelona_1992)**

# %%
url='https://es.wikipedia.org/wiki/Juegos_Ol%C3%ADmpicos_de_Barcelona_1992' # 1er paso, url

# %%
html=req.get(url).text   # 2º paso, html

# %%
soup=bs(html, 'html.parser')   # 3er paso sopa, y ya tenemos html

# %%
tabla=soup.find_all('table')[-1]

# %%
elem=tabla.find('a')

elem  # caja tag a
# Out:
# <a href="/wiki/Control_de_autoridades" title="Control de autoridades">Control de autoridades</a>

# %%
elem.text   # contenido de la caja
# Out:
# 'Control de autoridades'

# %%
elem.contents   # contenido como lista
# Out:
# ['Control de autoridades']

# %%
elem.attrs  # stickers en la tapa de la caja
# Out:
# {'href': '/wiki/Control_de_autoridades', 'title': 'Control de autoridades'}

# %%
 elem.attrs['href']
# Out:
# '/wiki/Control_de_autoridades'

# %%
medallero=soup.find_all('table')[-4]

type(medallero)
# Out:
# bs4.element.Tag

# %%
med_paises=[]

for f in medallero.find_all('tr'):  # bucle por filas de la tabla
    
    fila=[e for e in f.find_all('td')]
    
    if len(fila)>0:
        
        pais={
            'nombre': fila[1].find('a').text.strip(),
            'oros': int(fila[2].text),
            'platas': int(fila[3].text),
            'bronces': int(fila[4].text),
            'total': int(fila[5].text)
        }
        
        med_paises.append(pais)
        
med_paises
# Out:
# [{'nombre': 'Equipo Unificado',
#   'oros': 45,
#   'platas': 38,
#   'bronces': 29,
#   'total': 112},
#  {'nombre': 'Estados Unidos',
#   'oros': 37,
#   'platas': 34,
#   'bronces': 37,
#   'total': 108},
#  {'nombre': 'Alemania', 'oros': 33, 'platas': 21, 'bronces': 28, 'total': 82},
#  {'nombre': 'China', 'oros': 16, 'platas': 22, 'bronces': 16, 'total': 54},
#  {'nombre': 'Cuba', 'oros': 14, 'platas': 6, 'bronces': 11, 'total': 31},
#  {'nombre': 'España', 'oros': 13, 'platas': 7, 'bronces': 2, 'total': 22},
#  {'nombre': 'Corea del Sur',
#   'oros': 12,
#   'platas': 5,
#   'bronces': 12,
#   'total': 29},
#  {'nombre': 'Hungría', 'oros': 11, 'platas': 12, 'bronces': 7, 'total': 30},
#  {'nombre': 'Francia', 'oros': 8, 'platas': 5, 'bronces': 16, 'total': 29},
#  {'nombre': 'Australia', 'oros': 7, 'platas': 9, 'bronces': 11, 'total': 27}]

# %%
pd.DataFrame(med_paises)
# Out:
#              nombre  oros  platas  bronces  total
# 0  Equipo Unificado    45      38       29    112
# 1    Estados Unidos    37      34       37    108
# 2          Alemania    33      21       28     82
# 3             China    16      22       16     54
# 4              Cuba    14       6       11     31
# 5            España    13       7        2     22
# 6     Corea del Sur    12       5       12     29
# 7           Hungría    11      12        7     30
# 8           Francia     8       5       16     29
# 9         Australia     7       9       11     27

# %% [markdown]
# $$$$
#
# **[Videoconsolas](https://es.wikipedia.org/wiki/Videoconsola)**

# %%
url='https://es.wikipedia.org/wiki/Videoconsola'

# %%
html=req.get(url).text

soup=bs(html, 'html.parser')

# %%
tablas=soup.find_all('table')

tabla=tablas[-2]

# %%
filas=tabla.find_all('tr')

filas=[f.text.strip().split('\n') for f in filas]

final=[]

for e in filas:
    tmp=[]
    
    for st in e:
        if st!='':
            tmp.append(st)
            
    final.append(tmp)
    
final[:3]
# Out:
# [['Fabricante', 'Consola', 'Lanzamiento', 'Unidades vendidas'],
#  ['Nintendo',
#   'Nintendo DS',
#   '11 de marzo de 2005',
#   '5.7\xa0millones (hasta 2012)[63]\u200b'],
#  ['Sony',
#   'PlayStation 2',
#   '24 de noviembre de 2000',
#   '5\xa0millones (hasta 2009)[64]\u200b']]

# %%
df=pd.DataFrame(final[1:], columns=final[0])

df
# Out:
#    Fabricante               Consola                           Lanzamiento  \
# 0    Nintendo           Nintendo DS                   11 de marzo de 2005
# 1        Sony         PlayStation 2               24 de noviembre de 2000
# 2        Sony         PlayStation 4               29 de noviembre de 2013
# 3    Nintendo                   Wii                8 de diciembre de 2006
# 4        Sony         PlayStation 3                   23 de marzo de 2007
# 5    Nintendo              Game Boy                    Enero de 1991[68]​
# 6        Sony  PlayStation Portable               1 de septiembre de 2005
# 7    Nintendo          Nintendo 3DS                   25 de marzo de 2011
# 8    Nintendo      Game Boy Advance              22 de junio de 2001[72]​
# 9    Nintendo                Switch                    3 de marzo de 2017
# 10       Sony           PlayStation              29 de septiembre de 1995
# 11  Microsoft              Xbox 360                2 de diciembre de 2005
# 12       Sega            Mega Drive  Septiembre-Octubre de 1990[77]​[78]​
# 13   Nintendo                  SNES               1 de junio de 1992[81]​
# 14       Sony      PlayStation Vita                 22 de febrero de 2012
# 15       Sega         Master System                             1987[83]​
# 16   Nintendo                   NES                             1988[84]​
# 17  Microsoft              Xbox One               22 de noviembre de 2013
# 18   Nintendo              GameCube                     3 de mayo de 2002
# 19       Sega             Dreamcast            14 de octubre de 1999[88]​
# 20       Sega                Saturn               7 de julio de 1995[90]​
# 21       Sony         PlayStation 5               19 de noviembre de 2020
# 22  Microsoft       Xbox Series X/S               10 de noviembre de 2020
#
#                          Unidades vendidas
# 0           5.7 millones (hasta 2012)[63]​
# 1             5 millones (hasta 2009)[64]​
# 2           3.3 millones (hasta 2019)[65]​
# 3           2.7 millones (hasta 2011)[66]​
# 4           2.7 millones (hasta 2014)[67]​
# 5           2.3 millones (hasta 1999)[69]​
# 6           2.1 millones (hasta 2009)[70]​
# 7             2 millones (hasta 2018)[71]​
# 8           1.6 millones (hasta 2004)[73]​
# 9          1.57 millones (hasta 2020)[74]​
# 10          1.4 millones (hasta 1999)[75]​
# 11              1 millón (hasta 2012)[76]​
# 12    Menos de 700 000 (hasta 1994)[n. 5]​
# 13               630 000 (hasta 1998)[81]​
# 14               600 000 (hasta 2015)[82]​
# 15               550 000 (hasta 1993)[62]​
# 16               440 000 (hasta 1993)[62]​
# 17  305 000[85]​~500 000[86]​ (hasta 2018)
# 18    Menos de 300 000 (hasta 2006)[n. 6]​
# 19               200 000 (hasta 2001)[89]​
# 20                70 000 (hasta 1997)[91]​
# 21                43 000 (hasta 2020)[92]​
# 22                14 100 (hasta 2020)[92]​

# %%
df.Lanzamiento=df.Lanzamiento.apply(lambda x: int(x.split('[')[0][-4:]))

df.head()
# Out:
#   Fabricante        Consola  Lanzamiento               Unidades vendidas
# 0   Nintendo    Nintendo DS         2005  5.7 millones (hasta 2012)[63]​
# 1       Sony  PlayStation 2         2000    5 millones (hasta 2009)[64]​
# 2       Sony  PlayStation 4         2013  3.3 millones (hasta 2019)[65]​
# 3   Nintendo            Wii         2006  2.7 millones (hasta 2011)[66]​
# 4       Sony  PlayStation 3         2007  2.7 millones (hasta 2014)[67]​

# %% [markdown]
# ### Ejemplo geolocalización por IP
#
# https://tools.keycdn.com/geo

# %% [markdown]
# **¿Dónde estoy?**

# %%
url='https://tools.keycdn.com/geo'

# %%
html=req.get(url).text

soup=bs(html, 'html.parser')

# %%
soup.find('div', id='geoResult')
# Out:
# <div class="mt-4" id="geoResult">
# <div class="bg-light medium rounded p-3">
# <p class="small text-uppercase text-muted font-weight-semi-bold line-height-headings mb-2">Location</p> <dl class="row mb-0">
# <dt class="col-4">City</dt><dd class="col-8 text-monospace">Humanes de Madrid</dd><dt class="col-4">Region</dt><dd class="col-8 text-monospace">Madrid (M)</dd><dt class="col-4">Postal code</dt><dd class="col-8 text-monospace">28970</dd><dt class="col-4">Country</dt><dd class="col-8 text-monospace">Spain (ES)</dd><dt class="col-4">Continent</dt><dd class="col-8 text-monospace">Europe (EU)</dd><dt class="col-4">Coordinates</dt><dd class="col-8 text-monospace">40.2493 (lat) / -3.8357 (long)</dd><dt class="col-4">Time</dt><dd class="col-8 text-monospace">2021-11-16 19:20:15 (Europe/Madrid)</dd> </dl>
# <p class="small text-uppercase text-muted font-weight-semi-bold line-height-headings mt-4 mb-2">Network</p>
# <dl class="row mb-0">
# <dt class="col-4">IP address</dt><dd class="col-8 text-monospace">213.99.35.27</dd><dt class="col-4">Hostname</dt><dd class="col-8 text-monospace">213.99.35.27</dd><dt class="col-4">Provider</dt><dd class="col-8 text-monospace">Telefonica De Espana</dd><dt class="col-4">ASN</dt><dd class="col-8 text-monospace">3352</dd> </dl>
# </div>
# <div class="mapael mt-4" id="geoMap">
# <div class="map position-relative"></div>
# </div>
# </div>

# %%
data=soup.find('div', id='geoResult')

conexion=[e.text for e in data.find_all('dd', class_="col-8 text-monospace")]

conexion
# Out:
# ['Humanes de Madrid',
#  'Madrid (M)',
#  '28970',
#  'Spain (ES)',
#  'Europe (EU)',
#  '40.2493 (lat) / -3.8357 (long)',
#  '2021-11-16 19:20:15 (Europe/Madrid)',
#  '213.99.35.27',
#  '213.99.35.27',
#  'Telefonica De Espana',
#  '3352']

# %% [markdown]
# **Búsqueda según IP**
#
# https://tools.keycdn.com/geo?host=137.255.90.7

# %%
ip='137.255.90.7'

url=f'https://tools.keycdn.com/geo?host={ip}'

# %%
html=req.get(url).text

soup=bs(html, 'html.parser')

# %%
data=soup.find('div', id='geoResult')

conexion=[e.text for e in data.find_all('dd', class_="col-8 text-monospace")]

conexion
# Out:
# ['Benin (BJ)',
#  'Africa (AF)',
#  '9.5 (lat) / 2.25 (long)',
#  '2021-11-16 19:20:16 (Africa/Porto-Novo)',
#  '137.255.90.7',
#  '137.255.90.7']

# %%
def findme(ip):
    url=f'https://tools.keycdn.com/geo?host={ip}'
    html=req.get(url).text
    soup=bs(html, 'html.parser')
    data=soup.find('div', id='geoResult')
    conexion=[e.text for e in data.find_all('dd', class_="col-8 text-monospace")]
    return conexion

# %%
findme('137.255.90.10')
# Out:
# ['Benin (BJ)',
#  'Africa (AF)',
#  '9.5 (lat) / 2.25 (long)',
#  '2021-11-16 19:20:16 (Africa/Porto-Novo)',
#  '137.255.90.10',
#  '137.255.90.10']

# %% [markdown]
# ### Ejemplo LinkedIn

# %%
def search(keywords, country, num_pages, n_secs, exp):
    
    URL='https://www.linkedin.com/jobs/search/'
    
    data=[]

    for i in range(num_pages):

        scrape_url=''.join([
                            URL,                        # url base
                            '?keywords=', keywords,     # palabras clave
                            '&location=', country,      # pais
                            '&f_TPR=', str(n_secs),          # segundos atras
                            '&f_E=', str(exp),               # experiencia
                            '&start=', str(i*25),            # numero de paginas
                            ])
        
        html=req.get(scrape_url).text
        
        soup=bs(html, 'html.parser')
        
        todos=soup.find_all('ul', {'class':'jobs-search__results-list'})

        jobs=[f for e in todos for f in e.find_all('li')]
        
        
        for j in jobs:
            
            try:
                titulo=j.find('span', class_="screen-reader-text").text.strip()
                 
                company=j.find('a', class_="hidden-nested-link").text.strip()

                location=j.find('span', class_="job-search-card__location").text.strip()

                desc=j.find('p', class_="job-search-card__snippet").text.strip()

                
                date=j.find('time', class_="job-search-card__listdate").attrs['datetime']

                link=j.find('a', class_="base-card__full-link").attrs['href']


                data.append({
                    'title': titulo,
                    'keywords': keywords,
                    'country': country,
                    'pages': num_pages,
                    'n_secs': n_secs,
                    'exp': exp,
                    'company': company,
                    'location': location,
                    'desc': desc,
                    'date': date,
                    'link': link
                })
                
            except:
                continue
            
    
    return data

# %%
search('python', 'España', 4, 3000000, 2)[0]
# Out:
# {'title': 'Recién graduados - Programación',
#  'keywords': 'python',
#  'country': 'España',
#  'pages': 4,
#  'n_secs': 3000000,
#  'exp': 2,
#  'company': 'everis',
#  'location': 'Barcelona, Catalonia, Spain',
#  'desc': 'En una empresa comprometida con el desarrollo de la sociedad de la que forma parte en donde a través de la fundación everis se ...',
#  'date': '2021-10-19',
#  'link': 'https://es.linkedin.com/jobs/view/reci%C3%A9n-graduados-programaci%C3%B3n-at-everis-2796843620?refId=1CKRptc9EsBdRnr4xyL95g%3D%3D&trackingId=sVTi%2FktYjpFn4Hvh9%2Bld0Q%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card'}

# %%
pd.DataFrame(search('python+data', 'España', 2, 3000000, 2))
# Out:
#                                                 title     keywords country  \
# 0                                        Data Analyst  python+data  España
# 1                               Junior Data Scientist  python+data  España
# 2                       Entry Level Software Engineer  python+data  España
# 3                         Entry Level - Data Engineer  python+data  España
# 4                                        Data Analyst  python+data  España
# 5                                        Data Analyst  python+data  España
# 6                                    Python Developer  python+data  España
# 7                                        Data Analyst  python+data  España
# 8                                      Data Scientist  python+data  España
# 9                 Consultor/a Junior Data & Analytics  python+data  España
# 10                                     Data Scientist  python+data  España
# 11                                     Data Scientist  python+data  España
# 12                          Machine Learning Engineer  python+data  España
# 13                        Analista Programador Python  python+data  España
# 14                                       Data-analyst  python+data  España
# 15                 Python Developer (Data Science jr)  python+data  España
# 16                                   Python Developer  python+data  España
# 17                      CONSULTOR DATA SCIENCE MADRID  python+data  España
# 18  Desarrollador de Python para proyectos Django ...  python+data  España
# 19  Consultor Junior Business Intelligence & Analy...  python+data  España
# 20                               Python Data Engineer  python+data  España
# 21  Consultor Junior Business Intelligence & Analy...  python+data  España
# 22                                     Data Scientist  python+data  España
# 23                       Consultor/a Data & Analytics  python+data  España
# 24               Ingeniero/a de Datos (Data Engineer)  python+data  España
# 25                        Software Developer (Python)  python+data  España
# 26  Desarrollador Python con Experiencia en Entorn...  python+data  España
# 27                           Junior Software Engineer  python+data  España
# 28                                      Data Engineer  python+data  España
# 29                             PYTHON / SQL DEVELOPER  python+data  España
#
#     pages   n_secs  exp                                            company  \
# 0       2  3000000    2                             Branded Research, Inc.
# 1       2  3000000    2                                        Coders Data
# 2       2  3000000    2                                  Parallel Partners
# 3       2  3000000    2                                    CCS Global Tech
# 4       2  3000000    2                                         Aceolution
# 5       2  3000000    2  USAMRIID , US Army Medical Research Institute ...
# 6       2  3000000    2                                     Insight Global
# 7       2  3000000    2                                 SRS Consulting Inc
# 8       2  3000000    2                                         Clarity AI
# 9       2  3000000    2                                                 EY
# 10      2  3000000    2                                       Glamping Hub
# 11      2  3000000    2                                     ThePineappleCo
# 12      2  3000000    2                                     ThePineappleCo
# 13      2  3000000    2                  PSS Tecnologias de la Informacion
# 14      2  3000000    2                                    Randstad España
# 15      2  3000000    2                                  M Digital Partner
# 16      2  3000000    2                                           Galejobs
# 17      2  3000000    2                               Management Solutions
# 18      2  3000000    2                                             Abalia
# 19      2  3000000    2                                                 EY
# 20      2  3000000    2                                             Triple
# 21      2  3000000    2                                                 EY
# 22      2  3000000    2                                             Cabify
# 23      2  3000000    2                                                 EY
# 24      2  3000000    2                                             Inetum
# 25      2  3000000    2                                             Omnios
# 26      2  3000000    2                                Ki-works Consulting
# 27      2  3000000    2                                FMIT Solutions S.L.
# 28      2  3000000    2                         Kognia Sports Intelligence
# 29      2  3000000    2                                Kenmei Technologies
#
#                                        location  \
# 0                                 San Diego, CA
# 1                          Texas, United States
# 2                                Northbrook, IL
# 3                                 San Diego, CA
# 4                                   Bothell, WA
# 5                       Colorado, United States
# 6                                 United States
# 7                                  San Jose, CA
# 8            Madrid, Community of Madrid, Spain
# 9            Madrid, Community of Madrid, Spain
# 10                    Seville, Andalusia, Spain
# 11                                        Spain
# 12             Greater Madrid Metropolitan Area
# 13           Madrid, Community of Madrid, Spain
# 14           Madrid, Community of Madrid, Spain
# 15                  Barcelona, Catalonia, Spain
# 16                       Mellid, Galicia, Spain
# 17           Madrid, Community of Madrid, Spain
# 18           Madrid, Community of Madrid, Spain
# 19           Madrid, Community of Madrid, Spain
# 20                  Barcelona, Catalonia, Spain
# 21                  Barcelona, Catalonia, Spain
# 22           Madrid, Community of Madrid, Spain
# 23           Madrid, Community of Madrid, Spain
# 24  Greater Palma de Mallorca Metropolitan Area
# 25                  Barcelona, Catalonia, Spain
# 26           Madrid, Community of Madrid, Spain
# 27                     Málaga, Andalusia, Spain
# 28            Sant Joan Despí, Catalonia, Spain
# 29           Greater Valencia Metropolitan Area
#
#                                                  desc        date  \
# 0   Branded Research Inc., (Branded) is looking fo...  2021-11-15
# 1   The ideal candidate's favourite words are lear...  2021-10-26
# 2   Experience in scripting languages (PHP, JavaSc...  2021-11-15
# 3   Experience with other relational databases, BI...  2021-11-10
# 4   Use SQL, Oracle, Python or other programming l...  2021-11-15
# 5   I am looking for a position that will make use...  2021-11-12
# 6   They will be responsible for Python developmen...  2021-11-15
# 7   Strong mathematical skills to help collect, me...  2021-11-15
# 8   If you’re a Data Scientist and you enjoy answe...  2021-11-15
# 9   En la actualidad, buscamos incorporar en nuest...  2021-11-06
# 10  To help us define and grow our product, we are...  2021-11-11
# 11  Experience in any of the Cloud technologies (A...  2021-11-02
# 12  Experience in any of the Cloud technologies (A...  2021-10-29
# 13  Buscamos un analista programador con experienc...  2021-11-15
# 14  Quedaron en la 5ª y 9ª posición respectivament...  2021-11-11
# 15  We are currently looking for a Sr Python Devel...  2021-11-11
# 16  Coordinar, colaborar y supervisar el desarroll...  2021-11-04
# 17  Valorable conocimiento de técnicas de modeliza...  2021-11-15
# 18  En Abalia seguimos creciendo y buscamos incorp...  2021-11-04
# 19  En Technology Consulting desarrollamos solucio...  2021-11-06
# 20  Past experience working on data related challe...  2021-11-10
# 21  En Technology Consulting desarrollamos solucio...  2021-11-06
# 22  We're looking for a great Data Scientist who b...  2021-10-19
# 23  Aumentar el valor de nuestro equipo de Data & ...  2021-11-13
# 24  Experiencia de al menos 3 años en proyectos de...  2021-11-15
# 25  A Python expert with strong programming skills...  2021-10-18
# 26  Experiencia mínima de 2 años en Python y entor...  2021-10-30
# 27  Our solutions are used by global brands to man...  2021-11-04
# 28  Kognia Sports Intelligence is seeking a Data E...  2021-11-04
# 29  You will be involved at the creation and exten...  2021-10-18
#
#                                                  link
# 0   https://www.linkedin.com/jobs/view/data-analys...
# 1   https://www.linkedin.com/jobs/view/junior-data...
# 2   https://www.linkedin.com/jobs/view/entry-level...
# 3   https://www.linkedin.com/jobs/view/entry-level...
# 4   https://www.linkedin.com/jobs/view/data-analys...
# 5   https://www.linkedin.com/jobs/view/data-analys...
# 6   https://www.linkedin.com/jobs/view/python-deve...
# 7   https://www.linkedin.com/jobs/view/data-analys...
# 8   https://es.linkedin.com/jobs/view/data-scienti...
# 9   https://es.linkedin.com/jobs/view/consultor-a-...
# 10  https://es.linkedin.com/jobs/view/data-scienti...
# 11  https://es.linkedin.com/jobs/view/data-scienti...
# 12  https://es.linkedin.com/jobs/view/machine-lear...
# 13  https://es.linkedin.com/jobs/view/analista-pro...
# 14  https://es.linkedin.com/jobs/view/data-analyst...
# 15  https://es.linkedin.com/jobs/view/python-devel...
# 16  https://es.linkedin.com/jobs/view/python-devel...
# 17  https://es.linkedin.com/jobs/view/consultor-da...
# 18  https://es.linkedin.com/jobs/view/desarrollado...
# 19  https://es.linkedin.com/jobs/view/consultor-ju...
# 20  https://es.linkedin.com/jobs/view/python-data-...
# 21  https://es.linkedin.com/jobs/view/consultor-ju...
# 22  https://es.linkedin.com/jobs/view/data-scienti...
# 23  https://es.linkedin.com/jobs/view/consultor-a-...
# 24  https://es.linkedin.com/jobs/view/ingeniero-a-...
# 25  https://es.linkedin.com/jobs/view/software-dev...
# 26  https://es.linkedin.com/jobs/view/desarrollado...
# 27  https://es.linkedin.com/jobs/view/junior-softw...
# 28  https://es.linkedin.com/jobs/view/data-enginee...
# 29  https://es.linkedin.com/jobs/view/python-sql-d...

# %%
html=req.get('https://www.linkedin.com/jobs/search/?keywords=data&location=España&f_TPR=300000&f_E=1&start=75').text

soup=bs(html, 'html.parser')

# %%
todos=soup.find_all('ul', {'class':'jobs-search__results-list'})

job=[f for e in todos for f in e.find_all('li')]

titulo=job[0].find('span', class_="screen-reader-text").text.strip()

company=job[0].find('a', class_="hidden-nested-link").text.strip()

location=job[0].find('span', class_="job-search-card__location").text.strip()

desc=job[0].find('p', class_="job-search-card__snippet").text.strip()

date=job[0].find('time', class_="job-search-card__listdate").attrs['datetime']

link=job[0].find('a', class_="base-card__full-link").attrs['href']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-defc6bc1d5a3> in <module>
#      11 desc=job[0].find('p', class_="job-search-card__snippet").text.strip()
#      12
# ---> 13 date=job[0].find('time', class_="job-search-card__listdate").attrs['datetime']
#      14
#      15 link=job[0].find('a', class_="base-card__full-link").attrs['href']
#
# AttributeError: 'NoneType' object has no attribute 'attrs'
